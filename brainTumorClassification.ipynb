# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os, shutil
import cv2
import matplotlib.image as mpimg
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot')

# %%
##Change pitutiary_tumor images name 
#Training Data
folder = "brain_tumor_classification_dataset/Training/pituitary_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "PT_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the Pitutiray Tumor Training Directory")
# Out:
# All files are renamed in the Pitutiray Tumor Training Directory

# %%
##Change no_tumor images name 
#Training Data
folder = "brain_tumor_classification_dataset/Training/no_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "NO_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the no Tumor Training Directory")
# Out:
# All files are renamed in the no Tumor Training Directory

# %%
##Change meningioma_tumor images name 
#Training Data
folder = "brain_tumor_classification_dataset/Training/meningioma_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "MT_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the meningioma_tumor Training Directory")
# Out:
# All files are renamed in the meningioma_tumor Training Directory

# %%
##Change glioma_tumor images name 
#Training Data
folder = "brain_tumor_classification_dataset/Training/glioma_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "GT_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the glioma_tumor Training Directory")
# Out:
# All files are renamed in the glioma_tumor Training Directory

# %%
##Change pitutiary_tumor images name 
#Testing Data
folder = "brain_tumor_classification_dataset/Testing/pituitary_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "PT_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the Pitutiray Tumor Testing Directory")
# Out:
# All files are renamed in the Pitutiray Tumor Testing Directory

# %%
##Change no_tumor images name 
#Testing Data
folder = "brain_tumor_classification_dataset/Testing/no_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "NO_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the no Tumor Testing Directory")
# Out:
# All files are renamed in the no Tumor Testing Directory

# %%
##Change meningioma_tumor images name 
#Testing Data
folder = "brain_tumor_classification_dataset/Testing/meningioma_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "MT_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the meningioma_tumor Testing Directory")
# Out:
# All files are renamed in the meningioma_tumor Testing Directory

# %%
##Change glioma_tumor images name 
#Testing Data
folder = "brain_tumor_classification_dataset/Testing/glioma_tumor/"
count = 1

for filename in os.listdir(folder):
    source = folder + filename
    destination = folder + "GT_" + str(count) + ".jpg"
    os.rename(source, destination)
    count+=1
print("All files are renamed in the glioma_tumor Testing Directory")
# Out:
# All files are renamed in the glioma_tumor Testing Directory

# %%
#Exploratory Data Analysis(EDA)

# %%
list_pitutary_tumor = os.listdir('brain_tumor_classification_dataset/Training/pituitary_tumor/')
number_files_pitutary = len(list_pitutary_tumor)
print("Number of Images in Training Pitutary Tumor: ",number_files_pitutary)
# Out:
# Number of Images in Training Pitutary Tumor:  827

# %%
list_no_tumor = os.listdir('brain_tumor_classification_dataset/Training/no_tumor/')
number_files_notumor = len(list_no_tumor)
print("Number of Images in Training no Tumor: ",number_files_notumor)
# Out:
# Number of Images in Training no Tumor:  395

# %%
list_meningioma_tumor = os.listdir('brain_tumor_classification_dataset/Training/meningioma_tumor/')
number_files_meningioma = len(list_meningioma_tumor)
print("Number of Images in Training meningioma_tumor: ",number_files_meningioma)
# Out:
# Number of Images in Training meningioma_tumor:  822

# %%
list_glioma_tumor = os.listdir('brain_tumor_classification_dataset/Training/glioma_tumor/')
number_files_glioma = len(list_glioma_tumor)
print("Number of Images in Training meningioma_tumor: ",number_files_glioma)
# Out:
# Number of Images in Training meningioma_tumor:  826

# %%
data = {'Pitutary Tumor': number_files_pitutary, 'No Tumor':number_files_notumor, 'Meningioma Tumor':number_files_meningioma, 'Glicoma Tumor':number_files_glioma}
typex = data.keys()
values = data.values()

fig = plt.figure(figsize=(5,7))
plt.bar(typex, values, color="red")
plt.xlabel("Data")
plt.ylabel("No of Brain Tumor Images")
plt.title("Count of Brain Tumor Imager")
plt.show()

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
def augumented_data(file_dir, n_generated_sample, save_to_dir):
    data_gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, height_shift_range=0.1, shear_range=0.1, brightness_range=(0.3, 0.1),
                      horizontal_flip=True, vertical_flip=True, fill_mode='nearest')
    for filename in os.listdir(file_dir):
        image = cv2.imread(file_dir + '/' + filename)
        image = image.reshape((1,) + image.shape)
        save_prefix = 'aug_' + filename[:-4]
        i=0
        for batch in data_gen.flow(x = image, batch_size=1, save_to_dir=save_to_dir, save_prefix=save_prefix, save_format="jpg"):
            i+=1
            if i > n_generated_sample:
                break

# %%
augumented_data(file_dir='brain_tumor_classification_dataset/Training/no_tumor/', n_generated_sample=2, save_to_dir='brain_tumor_classification_dataset/Training/no_tumor_aug/')

# %%
list_no_tumor_aug = os.listdir('brain_tumor_classification_dataset/Training/no_tumor_aug/')
number_files_notumor_aug = len(list_no_tumor_aug)
print("Number of Images in Training no Tumor: ",number_files_notumor_aug)
# Out:
# Number of Images in Training no Tumor:  1185

# %%
data = {'Pitutary Tumor': number_files_pitutary, 'No Tumor':number_files_notumor_aug, 'Meningioma Tumor':number_files_meningioma, 'Glicoma Tumor':number_files_glioma}
typex = data.keys()
values = data.values()

fig = plt.figure(figsize=(5,7))
plt.bar(typex, values, color="red")
plt.xlabel("Data")
plt.ylabel("No of Brain Tumor Images")
plt.title("Count of Brain Tumor Imager")
plt.show()

# %%
X_train = []
Y_train = []
image_size = 150
labels = ['glioma_tumor','meningioma_tumor','no_tumor','pituitary_tumor']
for i in labels:
    folderPath = os.path.join('brain_tumor_classification_dataset/Training/',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)
        
for i in labels:
    folderPath = os.path.join('brain_tumor_classification_dataset/Testing/',i)
    for j in os.listdir(folderPath):
        img = cv2.imread(os.path.join(folderPath,j))
        img = cv2.resize(img,(image_size,image_size))
        X_train.append(img)
        Y_train.append(i)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
from sklearn.utils import shuffle
X_train,Y_train = shuffle(X_train,Y_train,random_state=101)
X_train.shape
# Out:
# (4054, 150, 150, 3)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_train,Y_train,test_size=0.1,random_state=101)

# %%
y_train_new = []
for i in y_train:
    y_train_new.append(labels.index(i))
y_train=y_train_new
y_train = tf.keras.utils.to_categorical(y_train)

y_test_new = []
for i in y_test:
    y_test_new.append(labels.index(i))
y_test=y_test_new
y_test = tf.keras.utils.to_categorical(y_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout
from sklearn.metrics import accuracy_score

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),activation = 'relu',input_shape=(150,150,3)))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(Conv2D(256,(3,3),activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(512,activation = 'relu'))
model.add(Dense(512,activation = 'relu'))
model.add(Dropout(0.3))
model.add(Dense(4,activation='softmax'))
# Out:
# C:\Users\anura\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 146, 146, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 73, 73, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 73, 73, 64)          │               0 │
# ...

# %%
model.compile(loss='categorical_crossentropy',optimizer='Adam',metrics=['accuracy'])

# %%
history = model.fit(X_train,y_train,epochs=20,validation_split=0.1)
# Out:
# Epoch 1/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 186s 2s/step - accuracy: 0.3151 - loss: 2.3076 - val_accuracy: 0.5425 - val_loss: 1.1332
# Epoch 2/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.5719 - loss: 1.0312 - val_accuracy: 0.6192 - val_loss: 0.9925
# Epoch 3/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.6551 - loss: 0.8539 - val_accuracy: 0.6630 - val_loss: 0.7573
# Epoch 4/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 174s 2s/step - accuracy: 0.7212 - loss: 0.7027 - val_accuracy: 0.7534 - val_loss: 0.6239
# Epoch 5/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.7658 - loss: 0.5926 - val_accuracy: 0.6795 - val_loss: 0.7331
# Epoch 6/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.7669 - loss: 0.5622 - val_accuracy: 0.8274 - val_loss: 0.5038
# Epoch 7/20
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - accuracy: 0.8262 - loss: 0.4344 - val_accuracy: 0.8000 - val_loss: 0.5254
# Epoch 8/20
# ...

# %%
model.save('braintumor.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))
fig = plt.figure(figsize=(14,7))
plt.plot(epochs,acc,'r',label="Training Accuracy")
plt.plot(epochs,val_acc,'b',label="Validation Accuracy")
plt.legend(loc='upper left')
plt.show()

# %%
img = cv2.imread('brain_tumor_classification_dataset/Testing/glioma_tumor/GT_1.JPG')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('brain_tumor_classification_dataset/Testing/glioma_tumor/GT_1.JPG')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
a=model.predict(img_array)
indices = a.argmax()
indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 0

# %%
from tensorflow.keras.preprocessing import image
img = image.load_img('brain_tumor_classification_dataset/Testing/meningioma_tumor/MT_1.JPG')
plt.imshow(img,interpolation='nearest')
plt.show()

# %%
img = cv2.imread('brain_tumor_classification_dataset/Testing/meningioma_tumor/MT_1.JPG')
img = cv2.resize(img,(150,150))
img_array = np.array(img)
img_array.shape
# Out:
# (150, 150, 3)

# %%
img_array = img_array.reshape(1,150,150,3)
img_array.shape
# Out:
# (1, 150, 150, 3)

# %%
a=model.predict(img_array)
indices = a.argmax()
indices
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1
